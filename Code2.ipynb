# %%
import numpy as np
# Generate 100 random numbers using a normal distribution with a mean of 0 and a standard deviation of 1 
random_numbers = np.random.randn(100)
print(random_numbers)
# Out:
# [-1.37847704e-01 -4.58920670e-02  1.46134826e+00  3.11240684e-01
#  -3.99539556e-01  4.83675772e-01 -1.74353989e-01  3.45087592e-01
#   1.71671936e+00  1.28700129e+00 -1.56581749e+00  7.86278960e-01
#  -1.14625543e+00  2.34098381e+00 -1.05590449e+00  5.30792787e-01
#   7.72349644e-01  1.35262510e+00 -3.76483955e-01 -1.35516874e+00
#  -7.58529540e-01 -1.91543802e+00 -8.33421652e-02 -4.47785201e-01
#  -1.71190684e+00 -1.32735446e+00  5.81510882e-01  5.56081813e-01
#   3.81304130e-01  3.85980114e-01  7.24877197e-01  1.32286655e-01
#  -2.17779033e-01  1.00179745e+00  6.17955044e-01 -8.86989537e-01
#  -9.62919218e-01 -8.68033291e-01  6.34160729e-01 -3.98260255e-01
#   6.52483261e-01  7.65927619e-02 -9.87001527e-01 -9.39718185e-01
#  -5.56349949e-01 -2.42340179e-01 -4.06113175e-02  1.02184497e+00
#   1.19380677e+00 -8.69877267e-01 -1.73964829e-03 -2.65193101e-02
#   3.71622691e-01 -5.96262206e-01  2.53821361e-01 -3.42307184e-01
#  -5.87649394e-01  4.92246291e-01 -1.09011831e+00 -7.58191166e-01
#   3.80353984e-01 -1.87228914e-01  1.81677531e-01  5.30511637e-01
#   3.97703699e-01 -1.02193387e+00 -7.44823193e-01 -9.03878491e-01
#   2.50903203e+00 -3.15957666e-01  6.40389789e-02 -1.61180652e+00
#  -6.17678440e-01 -5.34065691e-01  1.23532204e+00  6.67809620e-01
#  -5.91918985e-01 -9.79466811e-01 -1.06775609e+00 -2.27616532e-01
#  -8.12330830e-01  1.38742438e+00 -5.04728243e-01  2.48209206e-01
#  -5.13675830e-01  4.56416370e-01  1.19026784e+00  7.15006171e-01
#   1.35992926e+00  2.67513634e-01 -1.57406958e+00  2.69026222e+00
#  -2.69086569e-01 -2.04902418e-01 -8.73595446e-01 -1.67594131e+00
#   1.50943927e+00 -1.34812235e+00  2.61881236e-01  5.55661167e-01]

# %%
mean = 5
std_dev = np.sqrt(0.1) # Standard deviation is the square root of variance
random_numbers = np.random.normal(mean, std_dev, 100)
print(random_numbers)
# Out:
# [4.53575479 5.26252175 5.17371831 5.02944263 4.93588638 4.72797305
#  5.2723249  4.66142171 5.26951362 4.99772912 5.06619455 4.83115447
#  4.79405322 4.82771045 5.42808946 4.87856651 5.19074819 5.01983481
#  5.42370501 4.73403183 5.25547646 4.72963437 4.89435375 4.8000625
#  5.73691526 4.84804726 5.15797529 5.08829105 4.44937596 4.46039967
#  4.70194154 5.18565537 4.62634011 4.9481734  4.66227373 5.52281202
#  4.77576892 5.18346625 4.97681053 5.40752252 4.81597348 4.83475469
#  5.16052116 4.46078772 4.73919976 4.54576879 4.77798804 5.28409165
#  5.19326803 5.61472825 5.00579526 5.13365139 5.22811889 5.4552938
#  5.17675765 5.03393513 5.25325375 6.0948511  5.08403673 5.10937747
#  4.97518035 4.56498719 5.46821772 5.17162958 5.32957456 4.64507595
#  5.02273564 5.00377595 4.86705595 5.22020546 4.88184048 5.08517988
#  5.13936982 5.14005932 5.31634534 5.05631163 5.03328753 5.04371128
#  4.90714967 4.49263727 4.72145595 5.20281114 5.15659461 5.44090398
#  5.38689902 4.9555753  5.65801765 4.40982077 5.19555331 5.41842828
#  4.89516306 5.18747159 5.37717324 5.06563866 5.03284392 5.13785072
#  5.25038374 4.99970009 5.22386926 5.05700453]

# %%
import matplotlib.pyplot as plt
# Define x values
x = np.linspace(-5, 13, 1000) # This range should cover all the curves well
# Define the means and standard deviations 
means = [0, 2, 4, 6, 8]
std_devs = [1, 0.5, 0.2, 1.5, 0.3]
# Plot each normal distribution curve
for mean, std_dev in zip(means, std_devs):
    y = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev)**2)
    plt.plot(x, y, label=f"μ={mean}, σ={std_dev}")
# Add legend, title, and labels
plt.legend()
plt.title("Normal Distributions with Different Means and Standard Deviations") 
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.grid(True) 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Parameters 
n_trials = 40 
p_success = 0.5 
n_samples = 100
# Generate random numbers from a binomial distribution 
samples = np.random.binomial(n_trials, p_success, n_samples)
# Plotting
plt.hist(samples, bins=np.arange(n_trials+2)-0.5, edgecolor="k", align='mid', rwidth=0.9) 
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.title('Histogram of 100 samples from Binomial Distribution') 
plt.xticks(np.arange(n_trials+1))
plt.grid(axis='y')
plt.show()

# %%
from scipy.stats import binom
# Define n and p parameter combinations 
params = [(20, 0.5), (30, 0.3), (40, 0.7), (50, 0.2), (60, 0.6)]
# Set the figure size plt.figure(figsize=(12, 8))
# Plot binomial PMF for each n and p combination 
for n, p in params:
    x = np.arange(0, n+1)
    y = binom.pmf(x, n, p)
    plt.plot(x, y, '-o', label=f'n={n}, p={p}')
# Set labels, title, and legend
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution PMF for Different n and p Values') 
plt.legend()
# Display the plot plt.show()

# %%
# Setting the random seed for reproducibility 
np.random.seed(0)
# Lambda value 
lmbda = 5
# Generate 100 random numbers from a Poisson distribution with lambda=5 
random_numbers = np.random.poisson(lmbda, 100)
print(random_numbers)
# Out:
# [ 9  5  6  5  5  8  4  5  4  3  3  7  3  3  4  5  2  1  7  7 10  5  8  8
#   6  4  4  3  1  5  6  5  5  4  1  7  2  7  6  2  6  5  7  5  4  5 10  6
#   4  7  3  2  2  6  2  5  3  6  2  4  4  4  8  7 11  3  4  1  4  5  1  2
#   2  5  5  5  7  8  4  6  4 10  3  8  5  7  3  8  2  1  4  4  4  4  6  4
#  12  1  6  3]

# %%
# Plot histogram
plt.hist(random_numbers, bins=np.arange(random_numbers.min(), random_numbers.max()+2) - 0.5, align='mid', edgecolor='black') 
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Numbers from Poisson Distribution') 
plt.xticks(np.arange(random_numbers.min(), random_numbers.max()+1)) 
plt.grid(axis='y')
plt.show()

# %%
# Setting the random seed for reproducibility 
np.random.seed(0)
# Define the PMF of Poisson distribution 
def poisson_pmf(k, lmbda):
    return (np.exp(-lmbda) * lmbda**k) / np.math.factorial(k)
# Lambda values
lambdas = [2, 4, 6, 8, 10]
# Generate k values (e.g., from 0 to 20 for clear visualization) 
k_values = np.arange(0, 21)
# Plot the PMF for each lambda value 
for lmbda in lambdas:
    probabilities = [poisson_pmf(k, lmbda) for k in k_values] 
    plt.plot(k_values, probabilities, label=f'λ={lmbda}', marker='o')
plt.title('Poisson Distribution PMF for Different λ Values') 
plt.xlabel('k')
plt.ylabel('Probability')
plt.legend()
plt.grid(True) 
plt.show()

# %%
# Parameters 
alpha = 2
beta = 5 
n_samples = 100
# Generate random numbers from a beta distribution 
samples = np.random.beta(alpha, beta, n_samples)
# Set the figure size 
plt.figure(figsize=(12, 8))
# Plotting
plt.hist(samples, bins=50, edgecolor="k", alpha=0.7) 
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 100 samples from Beta Distribution (α=2, β=5)') 
plt.grid(axis='y')
plt.show()

# %%
from scipy.stats import beta
# Define alpha and beta parameter combinations 
params = [
(2, 5), (5, 2), (3, 3), (0.5, 0.5), (2, 8)
]
# Prepare x values for plotting 
x = np.linspace(0, 1, 1000)
# Set the figure size 
plt.figure(figsize=(12, 8))
# Plot beta PDF for each alpha and beta combination 
for a, b in params:
    y = beta.pdf(x, a, b)
    plt.plot(x, y, label=f'α={a}, β={b}')
# Set labels, title, and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Beta Distribution PDF for Different α and β Values')
plt.legend()
# Display the plot plt.show()

# %%
from scipy import stats
# Sample data 
sample_mean = 99 
sample_std_dev = 3
n = 30 
confidence_level = 0.95
# Calculate the standard error 
standard_error = sample_std_dev / np.sqrt(n)
# Calculate the confidence interval 
ci = stats.t.interval(
confidence_level, df=n-1, loc=sample_mean, scale=standard_error
# Confidence level
# Degrees of freedom # Sample mean
# Standard error
)
print("95% Confidence Interval:", ci)
# Out:
# 95% Confidence Interval: (97.8797815897257, 100.1202184102743)

# %%
# Sample data 
sample_mean = 99 
sample_std_dev = 3 
n = 30
# Calculate the standard error 
standard_error = sample_std_dev / np.sqrt(n)
# Calculate the half-width of the 95% CI using the t-distribution 
alpha = 0.05 # for a 95% CI
t_value = stats.t.ppf(1 - alpha/2, df=n-1)
half_width = t_value * standard_error
# Calculate the relative half-width 
relative_half_width = half_width / sample_mean
print("Relative Half-Width:", relative_half_width)
# Out:
# Relative Half-Width: 0.011315337477518178

# %%
# Define the probabilities and sizes 
probabilities = [0.1, 0.25, 0.5]
sizes = [200, 500, 1000, 2000, 5000, 10000] 
iterations = 5
# Function to calculate the confidence interval 
def calculate_CI(data, alpha=0.05):
    sample_mean = np.mean(data)
    standard_error = np.std(data, ddof=1) / np.sqrt(len(data))
    t_value = stats.t.ppf(1 - alpha/2, df=len(data)-1)
    half_width = t_value * standard_error
    return (sample_mean - half_width, sample_mean + half_width), half_width / sample_mean
for p in probabilities: 
    print(f"Probability: {p}") 
    for n in sizes:
        print(f"\tSize: {n}")
        for i in range(iterations):
            # Generate random numbers using binomial distribution 
            data = np.random.binomial(2500, p, n)
            # Calculate the confidence interval and relative half-width 
            CI, RHW = calculate_CI(data)
            print(f"\t\tIteration {i + 1}: CI = {CI}, RHW = {RHW}")
# Out:
# Probability: 0.1
# 	Size: 200
# 		Iteration 1: CI = (249.88210634940157, 253.98789365059844), RHW = 0.0081485051723597
# 		Iteration 2: CI = (247.49493553971735, 252.06506446028266), RHW = 0.009148308352480802
# 		Iteration 3: CI = (248.28875152318182, 252.29124847681817), RHW = 0.007995718873379529
# 		Iteration 4: CI = (249.1602884766505, 253.7097115233495), RHW = 0.00904691679101762
# 		Iteration 5: CI = (247.6020804349916, 251.7679195650084), RHW = 0.008342189418701176
# 	Size: 500
# 		Iteration 1: CI = (249.92250308609005, 252.57349691390993), RHW = 0.005275651602838394
# 		Iteration 2: CI = (247.10896755961554, 249.72303244038446), RHW = 0.0052614664127288895
# 		Iteration 3: CI = (248.90980884344003, 251.55819115655999), RHW = 0.0052918114906846175
# 		Iteration 4: CI = (247.97659895246508, 250.7234010475349), RHW = 0.005507924794605625
# 		Iteration 5: CI = (248.7981957007477, 251.38580429925233), RHW = 0.005173313417671539
# 	Size: 1000
# 		Iteration 1: CI = (249.09188082635987, 250.99211917364013), RHW = 0.0037998383217224354
# 		Iteration 2: CI = (248.4826844597417, 250.3533155402583), RHW = 0.0037499921427414764
# 		Iteration 3: CI = (249.0580203673084, 250.93397963269163), RHW = 0.0037519785624234364
# 		Iteration 4: CI = (248.6991119825026, 250.50888801749744), RHW = 0.0036252945365355844
# 		Iteration 5: CI = (248.52365088462108, 250.40634911537893), RHW = 0.0037734716909342794
# 	Size: 2000
# 		Iteration 1: CI = (249.9369933867008, 251.29500661329922), RHW = 0.0027093506132857435
# 		Iteration 2: CI = (249.2511131234975, 250.54088687650247), RHW = 0.002580621044364357
# 		Iteration 3: CI = (249.53178811838185, 250.80321188161813), RHW = 0.0025411449593498252
# 		Iteration 4: CI = (249.28764771242032, 250.58035228757967), RHW = 0.002586091878574587
# 		Iteration 5: CI = (248.84671137018412, 250.18728862981587), RHW = 0.0026863445369088145
# 	Size: 5000
# 		Iteration 1: CI = (249.79959347953925, 250.62680652046075), RHW = 0.0016530163894660917
# 		Iteration 2: CI = (249.82296408455653, 250.66143591544346), RHW = 0.0016753206111657936
# 		Iteration 3: CI = (249.29244557839718, 250.1319544216028), RHW = 0.0016809527992738221
# 		Iteration 4: CI = (249.6885010175447, 250.51429898245533), RHW = 0.0016509263141083015
# 		Iteration 5: CI = (249.40215431195026, 250.23744568804972), RHW = 0.0016717877768284402
# 	Size: 10000
# 		Iteration 1: CI = (249.65718395685954, 250.25741604314047), RHW = 0.0012006692468692274
# 		Iteration 2: CI = (249.59453717877565, 250.18286282122435), RHW = 0.0011771753633691938
# 		Iteration 3: CI = (249.74678648469276, 250.3278135153072), RHW = 0.001161880708627137
# 		Iteration 4: CI = (249.53864130306638, 250.1237586969336), RHW = 0.0011710254641277916
# 		Iteration 5: CI = (249.5619014895012, 250.1538985104988), RHW = 0.0011846674069493101
# Probability: 0.25
# 	Size: 200
# 		Iteration 1: CI = (623.1774480914058, 629.3025519085942), RHW = 0.004890380538761696
# 		Iteration 2: CI = (623.0852495437582, 629.0547504562419), RHW = 0.004767438874633569
# 		Iteration 3: CI = (621.9900535112395, 628.4299464887606), RHW = 0.0051501839202197615
# 		Iteration 4: CI = (623.8887800772982, 629.8012199227019), RHW = 0.004716030155304566
# 		Iteration 5: CI = (620.4571474442185, 626.9628525557815), RHW = 0.005215328527330702
# 	Size: 500
# 		Iteration 1: CI = (621.1876569284443, 625.0083430715556), RHW = 0.003065878997454003
# 		Iteration 2: CI = (624.3752357627707, 628.1887642372294), RHW = 0.003044577741703292
# 		Iteration 3: CI = (623.8622512254232, 627.6857487745768), RHW = 0.0030550147091071562
# 		Iteration 4: CI = (623.8440678112937, 627.6639321887063), RHW = 0.0030522093166104754
# 		Iteration 5: CI = (622.7003755747776, 626.4076244252224), RHW = 0.002967916985916977
# 	Size: 1000
# 		Iteration 1: CI = (622.9848064166023, 625.7091935833977), RHW = 0.002181789266862409
# 		Iteration 2: CI = (623.5213785520539, 626.242621447946), RHW = 0.0021774054108553583
# 		Iteration 3: CI = (624.1681695201568, 626.8518304798432), RHW = 0.002145178302254456
# 		Iteration 4: CI = (623.6675344820882, 626.3984655179119), RHW = 0.0021846294802223415
# 		Iteration 5: CI = (623.5701890741163, 626.2678109258836), RHW = 0.0021583772070998424
# 	Size: 2000
# 		Iteration 1: CI = (625.2903752773597, 627.1806247226403), RHW = 0.0015092161377634583
# 		Iteration 2: CI = (624.1227899932051, 625.981210006795), RHW = 0.0014866123247265467
# 		Iteration 3: CI = (624.7152798253333, 626.6127201746667), RHW = 0.001516341318449975
# 		Iteration 4: CI = (623.8268117262671, 625.7691882737329), RHW = 0.0015544036212229299
# 		Iteration 5: CI = (624.2330897862537, 626.1729102137463), RHW = 0.0015513524627141376
# 	Size: 5000
# 		Iteration 1: CI = (624.4548052927903, 625.6647947072097), RHW = 0.000967898922966635
# 		Iteration 2: CI = (624.2830232677388, 625.4733767322612), RHW = 0.0009524683886574855
# 		Iteration 3: CI = (624.2248355466302, 625.4335644533699), RHW = 0.0009672474547761554
# 		Iteration 4: CI = (624.6538381943218, 625.8285618056783), RHW = 0.0009394163495275851
# 		Iteration 5: CI = (624.497471970908, 625.7077280290921), RHW = 0.0009680459321270323
# 	Size: 10000
# 		Iteration 1: CI = (624.6150069037345, 625.4655930962655), RHW = 0.0006804250802156344
# 		Iteration 2: CI = (624.3712329834676, 625.2179670165323), RHW = 0.0006776099161746498
# 		Iteration 3: CI = (624.5272878103348, 625.3769121896652), RHW = 0.0006797515996268825
# 		Iteration 4: CI = (624.8741478330708, 625.7250521669293), RHW = 0.0006803973118314652
# 		Iteration 5: CI = (624.6567888429673, 625.5022111570328), RHW = 0.0006762518320193849
# Probability: 0.5
# 	Size: 200
# 		Iteration 1: CI = (1249.2730430576198, 1256.6269569423803), RHW = 0.0029346398039667865
# 		Iteration 2: CI = (1246.7491026960713, 1252.8708973039286), RHW = 0.0024490901048388543
# 		Iteration 3: CI = (1246.0956967267741, 1253.664303273226), RHW = 0.0030277332809757933
# 		Iteration 4: CI = (1246.965732984748, 1253.7542670152518), RHW = 0.002714631798243689
# 		Iteration 5: CI = (1246.857640712845, 1253.3823592871547), RHW = 0.0026096369045810652
# 	Size: 500
# 		Iteration 1: CI = (1249.150357593581, 1253.5896424064188), RHW = 0.0017737698733538392
# 		Iteration 2: CI = (1248.5349051174276, 1252.7930948825724), RHW = 0.001702371606260696
# 		Iteration 3: CI = (1246.150167452103, 1250.333832547897), RHW = 0.0016758229156661156
# 		Iteration 4: CI = (1248.5363764171243, 1253.051623582876), RHW = 0.0018049523605611338
# 		Iteration 5: CI = (1247.0509250327668, 1251.553074967233), RHW = 0.0018018661358367345
# 	Size: 1000
# 		Iteration 1: CI = (1249.1797579914232, 1252.4382420085767), RHW = 0.0013025505961155774
# 		Iteration 2: CI = (1250.3506040752638, 1253.635395924736), RHW = 0.0013118251657445509
# 		Iteration 3: CI = (1247.6743160658677, 1250.7636839341324), RHW = 0.0012365197248299584
# 		Iteration 4: CI = (1248.2627832789963, 1251.4752167210036), RHW = 0.0012851080561271377
# 		Iteration 5: CI = (1247.915312699252, 1250.956687300748), RHW = 0.00121709899566535
# 	Size: 2000
# 		Iteration 1: CI = (1249.6440335230068, 1251.8689664769931), RHW = 0.0008894348955958084
# 		Iteration 2: CI = (1249.75365295118, 1251.93134704882), RHW = 0.0008704909281705467
# 		Iteration 3: CI = (1248.068482644885, 1250.264517355115), RHW = 0.0008790000012927517
# 		Iteration 4: CI = (1248.762923189227, 1250.935076810773), RHW = 0.0008689664197618026
# 		Iteration 5: CI = (1249.1138596340704, 1251.2711403659298), RHW = 0.0008627794247122774
# 	Size: 5000
# 		Iteration 1: CI = (1249.2417982903123, 1250.6178017096875), RHW = 0.0005504322800269203
# 		Iteration 2: CI = (1249.3369614499627, 1250.7226385500373), RHW = 0.0005542576265281047
# 		Iteration 3: CI = (1249.1990565703663, 1250.5881434296339), RHW = 0.0005556820433625024
# 		Iteration 4: CI = (1249.379842803847, 1250.754557196153), RHW = 0.0005498561966532989
# 		Iteration 5: CI = (1249.6795141929397, 1251.0764858070602), RHW = 0.0005586197190452036
# 	Size: 10000
# 		Iteration 1: CI = (1249.4063479493948, 1250.395252050605), RHW = 0.0003955930347473198
# 		Iteration 2: CI = (1249.038783791523, 1250.029816208477), RHW = 0.0003965607094396176
# 		Iteration 3: CI = (1249.913348750731, 1250.8900512492687), RHW = 0.0003905554905025489
# 		Iteration 4: CI = (1249.0607734018215, 1250.0398265981787), RHW = 0.00039176221891875534
# 		Iteration 5: CI = (1249.378677179156, 1250.358322820844), RHW = 0.0003918994845009979

# %%
# Define the probabilities and sizes 
probabilities = [0.1, 0.25, 0.5]
sim_sizes = [200, 500, 1000, 2000, 5000, 10000] 
iterations = 5
n=2500 #No of cases
# Function to calculate the confidence interval 
def calculate_CI(data, alpha=0.05):
    sample_mean = np.mean(data)
    standard_error = np.std(data, ddof=1) / np.sqrt(len(data))
    t_value = stats.t.ppf(1 - alpha/2, df=len(data)-1) 
    half_width = t_value * standard_error
    return half_width / sample_mean
results = {}
for p in probabilities: 
    rhw_values = []
    for size in sim_sizes:
        avg_rhw = np.mean([calculate_CI(np.random.binomial(n, p, size)) for _ in range(iterations)]) 
        rhw_values.append(avg_rhw)
    results[p] = rhw_values
# Plotting the results plt.figure(figsize=(10,6))
for p, rhw_values in results.items():
    plt.plot(sim_sizes, rhw_values, label=f'Probability {p}', marker='o')
plt.xlabel('Number of Simulations')
plt.ylabel('Relative Half-Width of 95% CI')
plt.title('Relative Half-Width of 95% CI vs. Number of Simulations') 
plt.legend()
plt.grid(True)
plt.show()

# %%
#Initialization of fixed parameters 
cases = 201
a1 = 0.59
a2 = 0.723
a3 = 0.128
population = 1019847
n_iter = 10
#Define alpha and beta values 
def getAlphaBeta(mu, sigma):
    alpha=(((1-mu)/sigma**2)-(1/mu))*mu**2 
    beta=((1/mu)-1)*alpha
    return alpha, beta

true_incidence = cases / population
cases_dist = np.random.binomial(n = population, p=true_incidence, size=n_iter) 
cases_dist
# Out:
# array([217, 206, 211, 231, 200, 217, 189, 216, 217, 196])

# %%
(alpha1,beta1) = getAlphaBeta(a1,0.05) #Varience = 0.5 will show an error 
a1_dist = np.random.beta(alpha1, beta1, size=n_iter)
(alpha2,beta2) = getAlphaBeta(a2,0.05)
a2_dist = np.random.beta(alpha2, beta2, size=n_iter)
(alpha3,beta3) = getAlphaBeta(a2,0.05)
a3_dist = np.random.beta(alpha3, beta3, size=n_iter)
crude_rate_dist = cases_dist / population 
crude_rate_dist
# Out:
# array([0.00021278, 0.00020199, 0.00020689, 0.0002265 , 0.00019611,
#        0.00021278, 0.00018532, 0.0002118 , 0.00021278, 0.00019219])

# %%
adjusted_rate_dist = crude_rate_dist / (a1_dist * a2_dist * a3_dist) 
adjusted_rate_dist
# Out:
# array([0.00066626, 0.00051561, 0.00056515, 0.00073016, 0.00057638,
#        0.0008374 , 0.00054139, 0.00072097, 0.00060745, 0.00052814])

# %%
#Initialization of fixed parameters 
numbers = (35, 80, 85)
a1 = (0.59, 0.59, 0.59)
a2 = (0.989, 0.988, 0.991) #DSH
a3 = (0.613, 0.613, 0.613) 
pop_changing = (77958, 173878, 588070) 
age_group = ('<2','2-4','5-15')
n_iter = 100000
incidence = [] 
lower_ci = [] 
upper_ci = []

#Define alpha and beta values 
def getAlphaBeta(mu, sigma):
    alpha=(((1-mu)/sigma**2)-(1/mu))*mu**2 
    beta=((1/mu)-1)*alpha
    return alpha, beta

#Calculate adjusted incidence for each year
for x in range(len(age_group)):
    # Define the distribution of cases
    true_incidence = numbers[x]/pop_changing[x]
    cases_dist = np.random.binomial(n=pop_changing[x], p=true_incidence, size=n_iter)
    # Define the distributions of the adjustment factors 
    (alpha1,beta1) = getAlphaBeta(a1[x],0.05) 
    (alpha2,beta2) = getAlphaBeta(a2[x],0.05) 
    (alpha3,beta3) = getAlphaBeta(a3[x],0.05)
    a1_dist = np.random.beta(alpha1, beta1, size=n_iter) 
    a2_dist = np.random.beta(alpha2, beta2, size=n_iter) 
    a3_dist = np.random.beta(alpha3, beta3, size=n_iter)
    # Calculate the crude incidence rate 
    crude_rate_dist = cases_dist / pop_changing[x]
    # Calculate the adjusted incidence rate
    adjusted_rate_dist = crude_rate_dist / (a1_dist * a2_dist * a3_dist) 
    incidence.append(np.mean(adjusted_rate_dist*100000))
    # Calculate the uncertainty intervals (e.g. 95% confidence intervals) for the adjusted incidence rate 
    lower_ci.append(np.percentile(adjusted_rate_dist*100000,2.5)) 
    upper_ci.append(np.percentile(adjusted_rate_dist*100000,97.5))
incidence

#Plotting the values
plt.plot(age_group, incidence, '#8F262A', linewidth=2, markersize=12) 
#plt.plot(year, lower_ci,'#B298CB', linewidth=2, markersize=12) 
#plt.plot(year, upper_ci,'#98CB98', linewidth=2, markersize=12) 
plt.fill_between(age_group, lower_ci, upper_ci, color='#8F262A', alpha=.15) 
plt.legend(['Adjusted incidence'])
plt.title("simulation of typhi incidence")
# Out:
# Text(0.5, 1.0, 'simulation of typhi incidence')
